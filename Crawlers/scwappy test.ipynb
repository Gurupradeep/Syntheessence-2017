# %%
import scwappy

# %%
scwapper = scwappy.eBayScwaper(scwappy.basePaths['Tablets'], verbose = True, driver='PhantomJS')

# %%
scwapper.scrape()
# Out:
# Items Completed: 1, Time Elapsed: -14.402840852737427
# Items Completed: 2, Time Elapsed: -24.810707092285156
# Items Completed: 3, Time Elapsed: -35.449546098709106
# Items Completed: 4, Time Elapsed: -56.81344485282898
# Items Completed: 5, Time Elapsed: -66.62831997871399
# Items Completed: 6, Time Elapsed: -76.16616821289062
# Items Completed: 7, Time Elapsed: -99.56580901145935
# Items Completed: 8, Time Elapsed: -112.67756509780884
# Items Completed: 9, Time Elapsed: -128.5444040298462
# Items Completed: 10, Time Elapsed: -141.2994499206543
# Items Completed: 11, Time Elapsed: -153.36026096343994
# Items Completed: 12, Time Elapsed: -159.21929717063904
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-681b396d380f> in <module>()
# ----> 1 scwapper.scrape()
#
# ...

# %%
scwapper.scraped_data
# Out:
#                                              ItemLink               Price  \
# 0   http://www.ebay.com/itm/NEW-10-1-Tablet-PC-And...    $79.66 to $89.99
# 1   http://www.ebay.com/itm/10-inch-Google-Android...              $89.99
# 2   http://www.ebay.com/itm/Apple-iPad-Pro-12-9-Wi...             $649.99
# 3   http://www.ebay.com/itm/Kobo-Aura-Digital-eBoo...              $55.95
# 4   http://www.ebay.com/itm/Kobo-Aura-H2O-Waterpro...             $143.00
# 5   http://www.ebay.com/itm/2016-NEW-Kobo-Aura-One...             $230.99
# 6   http://www.ebay.com/itm/Kobo-Touch-eReader-905...              $33.95
# 7   http://www.ebay.com/itm/N98-9-Inch-Android-4-4...              $69.97
# 8   http://www.ebay.com/itm/VOYO-Q101-10-1-inch-4G...             $115.99
# 9   http://www.ebay.com/itm/SAMSUNG-GALAXY-TAB-E-L...              $69.95
# 10  http://www.ebay.com/itm/Apple-iPad-4th-Generat...  $169.00 to $179.95
# 11  http://www.ebay.com/itm/Teclast-P80h-Tablet-PC...              $20.48
# ...
